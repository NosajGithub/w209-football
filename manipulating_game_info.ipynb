# %%
import pandas as pd
import numpy as np

data = pd.read_csv("game_info_all2.csv")
data
# Out:
#       season away_team                     game_url home_team  \
# 0       2009       oti  /boxscores/200909100pit.htm       pit
# 1       2009       mia  /boxscores/200909130atl.htm       atl
# 2       2009       phi  /boxscores/200909130car.htm       car
# 3       2009       den  /boxscores/200909130cin.htm       cin
# 4       2009       min  /boxscores/200909130cle.htm       cle
# 5       2009       jax  /boxscores/200909130clt.htm       clt
# 6       2009       sfo  /boxscores/200909130crd.htm       crd
# 7       2009       chi  /boxscores/200909130gnb.htm       gnb
# 8       2009       nyj  /boxscores/200909130htx.htm       htx
# 9       2009       det  /boxscores/200909130nor.htm       nor
# 10      2009       was  /boxscores/200909130nyg.htm       nyg
# 11      2009       kan  /boxscores/200909130rav.htm       rav
# 12      2009       ram  /boxscores/200909130sea.htm       sea
# 13      2009       dal  /boxscores/200909130tam.htm       tam
# ...

# %%
# # year|team|games
# pd.DataFrame({'count' : data.groupby(['season','away_team'])['away_team'].count()}).reset_index().to_csv("year_away_count.csv")

# # year|home_team|games
# pd.DataFrame({'count' : data.groupby(['season','home_team'])['away_team'].count()}).reset_index().to_csv("year_home_count.csv")

# # year|roof|games
# pd.DataFrame({'count' : data.groupby(['season','roof'])['away_team'].count()}).reset_index().to_csv("year_roof_count.csv")

# # year|surface|games
# pd.DataFrame({'count' : data.groupby(['season','surface'])['away_team'].count()}).reset_index().to_csv("year_surface_count.csv")
